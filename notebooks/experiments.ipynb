# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
from src.data_generation import generate_linear_data
from src.visualize import plot_data_with_line
from sklearn.linear_model import LinearRegression
from src.data_generation import generate_quadratic_data
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge

# %%
model = LinearRegression()

model = LinearRegression()
model.fit(x, y)
preds = model.predict(x)

print("Predictions:", preds)
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Predictions: [7.85882187 5.72018765 6.34768996 6.01306158 6.65669547 8.44173893
#  7.02222503 8.16521184 6.35852856 5.70580989 8.65140413 8.00671794
#  7.57954344 6.89346688 7.65815195 8.34474604 7.41947735 7.78513717
#  6.74016978 5.79105802 6.02357517 8.98711881 6.48922892 6.28765599
#  7.53573272 7.24003625 7.09109695 7.32612781 8.93413759 6.53334997
#  8.09297686 8.19866498 6.95520697 7.76720147 6.77613487 6.01788661
#  8.97713222 7.29364742 8.35085954 5.8322406  6.21781013 7.08922706
#  6.65764849 6.35670046 6.83351705 6.15719221 5.6115902  6.77345256
#  7.44236597 6.41597558 6.20083847 6.57031441 8.53682646 8.2065241
#  8.35059195 6.71619826 8.95864759 6.42326935 6.23936001 6.08513504
#  8.76525443 7.53673968 5.76482798 6.80597047 8.91380167 6.59295627
#  7.80780224 5.73990497 8.99262451 6.88007999 7.22709374 6.89682591
#  6.35288147 8.94925585 5.94433085 6.85629867 6.00809492 6.11571349
#  6.62420467 7.79507117 7.18840185 7.52119029 6.83617206 8.05281123
# ...

# %%
# Generate data
x, y = generate_linear_data(noise_std=2.0)

# Train model
model = LinearRegression()
model.fit(x, y)

# Predict
y_pred = model.predict(x)

# Plot
plot_data_with_line(x, y, y_pred)

# %%
x, y = generate_quadratic_data(noise_std=2.0)

model = LinearRegression()
model.fit(x, y)

y_pred = model.predict(x)

plot_data_with_line(x, y, y_pred, title="Linear Regression on Quadratic Data")

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)

# TODO:
# 1. Transform x → x_poly
# 2. Fit model on x_poly
# 3. Predict

# %%
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)

# %%
x, y = generate_quadratic_data(noise_std=2.0)

poly = PolynomialFeatures(degree=2)
x_poly = x_poly = poly.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)

y_pred = model.predict(x_poly)
plot_data_with_line(x, y, y_pred, title="Polynomial Features on Quadratic Data")

# %%
poly = PolynomialFeatures(degree=10)

x_poly = poly.fit_transform(x)

model = LinearRegression()
model.fit(x_poly, y)

y_pred = model.predict(x_poly)
plot_data_with_line(x, y, y_pred, title="Polynomial Features on Quadratic Data")

# %%
model = Ridge(alpha=500.0)  # try different values

model.fit(x_poly, y)

y_pred = model.predict(x_poly)
plot_data_with_line(x, y, y_pred, title="Showing Ridge Regression with Polynomial Features")
